# %% [markdown]
# This notebook has for goal to preprocess the Kaggle Olympic 2024 dataset.
#
# The original dataset can be found [here](https://www.kaggle.com/datasets/piterfm/paris-2024-olympic-summer-games)
#
# # Description of the dataset before processing
#
# The Kaggle Olympic 2024 (KO) is a dataset containing the description of all athletes who participated in the Olympic games of 2024. It is already well curated for most general tasks (~~but this project is anything but general~~) but will require some additional curation given our usage of the names.
#
# With 11114 entries, it is our biggest dataset.
#
# # Preprocessing tasks
#
# Firstly, the services that can make use of the country of origin of the name, for the most part, only accept the ISO code of the country. Since the country is only registered as a string here, we use pycountry to make a fuzzy search of the string and return the ISO code.
#
# Secondly, we'll check for duplicate on the basis of the full name and the country, and remove them.
#
# Then, names that are considered difficult needs to be flagged. Names are considered difficult if they contains any of the following :
# - Middle name
# - No last name
# - Double barreled names (ex : Smith-Jones)
# - ASCII characters (any character that is not the standard a-zA-Z. All accents are included here too.)
# - Numbers in the name
# - trailing spaces and other irregularities with blank spaces.
# - Potential punctuation in the name (ex: Adam J.)
#
# A visual inspection of a part of the dataset seems to allude to the fact that it follows a structure for the full name. The last name is written in all upper caps, while the first name has only the first letter capitalized. This would mean that, at least for name that NOT flagged earlier, separating them into first and last name can be done via code. Going forward, this is assumed to be true.

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import pycountry

# %%
df = pd.read_csv('../../data/rawData/kaggleOlympic2024/KaggleOlympic2024.csv')

# %%
df.head()
# Out:
#                 name     name_short            name_tv gender function  \
# 0   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN   Male  Athlete
# 1     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN   Male  Athlete
# 2    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN   Male  Athlete
# 3  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN   Male  Athlete
# 4    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN   Male  Athlete
#
#   country_code  country country_long nationality nationality_long  \
# 0          ARM  Armenia      Armenia     Armenia          Armenia
# 1          ARM  Armenia      Armenia     Armenia          Armenia
# 2          ARM  Armenia      Armenia     Armenia          Armenia
# 3          ARM  Armenia      Armenia     Armenia          Armenia
# 4          ARM  Armenia      Armenia     Armenia          Armenia
#
#   nationality_code  birth_date birth_place birth_country residence_place  \
# 0              ARM  21/10/1991      GYUMRI       Armenia          GYUMRI
# 1              ARM  22/01/1999     YEREVAN       Armenia         YEREVAN
# 2              ARM  21/12/1996         NaN           NaN         YEREVAN
# 3              ARM  22/11/1999       MASIS       Armenia         YEREVAN
# 4              ARM  27/10/1999   POKR VEDI       Armenia             NaN
#
#   residence_country                        lang
# 0           Armenia  Armenian, English, Russian
# 1           Armenia                    Armenian
# 2           Armenia                    Armenian
# 3           Armenia                    Armenian
# 4           Armenia           Armenian, Russian

# %% [markdown]
# ## Adding ISO code
#
# The dataset already provide an ISO code for the country and nationality of the participants, but it is in another ISO standard (ISO 3166-1 alpha 3, where as the services overwhelmingly used ISO 3166-1 alpha 2). Additionaly, this ISO code is set to indicate the country's team the athlete is playing for, not their own birth country, which is likely to carry a stronger influence on how they are named.
#
# As such, the procedure is as follow :
# 1. We use pycountry to fuzzy search the 'birth_country' columns to return a matching ISO code in the correct standard
# 2. If this fails, we then use the nationality then country of the athlete to define the ISO alpha 2 code.
# 3. If this fails, either because the values are missing or the fuzzy search fails, we use the 'country_code' to still fill in a valid ISO code.
#
# After this, some error and inconcistencies where noticed in the ISO code used in the dataset. For example, the code noted for the Islamic Republic of Iran was 'IRI', when the real code (according to Wikipedia as of 04/09/2025) is 'IRN'

# %%
def findISOCode(row):
    candidates = [row.get("birth_country"), row.get('nationality'), row.get('country')]

    for birth_country in candidates:
        if isinstance(birth_country, str) and birth_country.strip():
            try:
                return pycountry.countries.search_fuzzy(birth_country)[0].alpha_2
            except LookupError:
                pass
    else : 
        try : 
            fallBack = row.get("country_code")
            return pycountry.countries.get(alpha_3=fallBack).alpha_2
        except AttributeError:
            
            return None

df["iso_country"] = df.apply(findISOCode, axis=1)
df.head()
# Out:
#                 name     name_short            name_tv gender function  \
# 0   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN   Male  Athlete
# 1     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN   Male  Athlete
# 2    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN   Male  Athlete
# 3  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN   Male  Athlete
# 4    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN   Male  Athlete
#
#   country_code  country country_long nationality nationality_long  \
# 0          ARM  Armenia      Armenia     Armenia          Armenia
# 1          ARM  Armenia      Armenia     Armenia          Armenia
# 2          ARM  Armenia      Armenia     Armenia          Armenia
# 3          ARM  Armenia      Armenia     Armenia          Armenia
# 4          ARM  Armenia      Armenia     Armenia          Armenia
#
#   nationality_code  birth_date birth_place birth_country residence_place  \
# 0              ARM  21/10/1991      GYUMRI       Armenia          GYUMRI
# 1              ARM  22/01/1999     YEREVAN       Armenia         YEREVAN
# 2              ARM  21/12/1996         NaN           NaN         YEREVAN
# 3              ARM  22/11/1999       MASIS       Armenia         YEREVAN
# 4              ARM  27/10/1999   POKR VEDI       Armenia             NaN
#
#   residence_country                        lang iso_country
# 0           Armenia  Armenian, English, Russian          AM
# 1           Armenia                    Armenian          AM
# 2           Armenia                    Armenian          AM
# 3           Armenia                    Armenian          AM
# 4           Armenia           Armenian, Russian          AM

# %%
na_isoCode = df['iso_country'].isna().sum()
print(f"The dataset has {na_isoCode} missing iso codes")

df_na_isoCode = df[df['iso_country'].isna()]
df_na_isoCode
# Out:
# The dataset has 113 missing iso codes
#                               name       name_short  \
# 77                 AL SAYEGH Safia      AL SAYEGH S
# 98                   ABDOLI Samyar         ABDOLI S
# 100    AL MARZOOQI Omar Abdul Aziz  AL MARZOOQI OAA
# 125                   SALIMI Arian         SALIMI A
# 126             BARKHORDARI Mehran    BARKHORDARI M
# ...                            ...              ...
# 9545                  ROBAN Handal          ROBAN H
# 9546              MALONEY Shafiqua        MALONEY S
# 10990                ALSHEHHI Maha       ALSHEHHI M
# 10991               ALFARSI Mariam        ALFARSI M
# 11051                   HAN An-Chi           HAN AC
#
#                            name_tv  gender function country_code  \
# 77                 Safia AL SAYEGH  Female  Athlete          UAE
# 98                   Samyar ABDOLI    Male  Athlete          IRI
# 100    Omar Abdul Aziz AL MARZOOQI    Male  Athlete          UAE
# 125                   Arian SALIMI    Male  Athlete          IRI
# 126             Mehran BARKHORDARI    Male  Athlete          IRI
# ...                            ...     ...      ...          ...
# 9545                  Handal ROBAN    Male  Athlete          VIN
# 9546              Shafiqua MALONEY  Female  Athlete          VIN
# 10990                Maha ALSHEHHI  Female  Athlete          UAE
# 10991               Mariam ALFARSI  Female  Athlete          UAE
# 11051                   HAN An-Chi  Female  Athlete          TPE
#
#                     country                   country_long  \
# 77              UA Emirates           United Arab Emirates
# 98                  IR Iran       Islamic Republic of Iran
# 100             UA Emirates           United Arab Emirates
# 125                 IR Iran       Islamic Republic of Iran
# 126                 IR Iran       Islamic Republic of Iran
# ...                     ...                            ...
# 9545   StVincent&Grenadines  St Vincent and the Grenadines
# 9546   StVincent&Grenadines  St Vincent and the Grenadines
# 10990           UA Emirates           United Arab Emirates
# 10991           UA Emirates           United Arab Emirates
# 11051        Chinese Taipei                 Chinese Taipei
#
#                 nationality               nationality_long nationality_code  \
# 77              UA Emirates           United Arab Emirates              UAE
# 98                  IR Iran       Islamic Republic of Iran              IRI
# 100             UA Emirates           United Arab Emirates              UAE
# 125                 IR Iran       Islamic Republic of Iran              IRI
# 126                 IR Iran       Islamic Republic of Iran              IRI
# ...                     ...                            ...              ...
# 9545   StVincent&Grenadines  St Vincent and the Grenadines              VIN
# 9546   StVincent&Grenadines  St Vincent and the Grenadines              VIN
# 10990           UA Emirates           United Arab Emirates              UAE
# 10991           UA Emirates           United Arab Emirates              UAE
# 11051        Chinese Taipei                 Chinese Taipei              TPE
#
#        birth_date     birth_place         birth_country      residence_place  \
# 77     23/09/2001             NaN                   NaN                  NaN
# 98     25/12/2002             NaN                   NaN                  NaN
# 100    28/03/2003             NaN                   NaN            ABU DHABI
# 125    16/12/2003      KERMANSHAH               IR Iran                  NaN
# 126    26/07/2000          QAZVIN               IR Iran                  NaN
# ...           ...             ...                   ...                  ...
# 9545   05/09/2002             NaN  StVincent&Grenadines  UNIVERSITY PARK, PA
# 9546   27/02/1999   RICHLAND PARK  StVincent&Grenadines     FAYETTEVILLE, AK
# 10990  12/07/2006             NaN                   NaN                  NaN
# 10991  15/01/2008             NaN                   NaN                DUBAI
# 11051  04/09/2004  CHINESE TAIPEI        Chinese Taipei           AUSTIN, TX
#
#       residence_country              lang iso_country
# 77                  NaN   Arabic, English        None
# 98                  NaN               NaN        None
# 100         UA Emirates   Arabic, English        None
# 125             IR Iran             Farsi        None
# 126             IR Iran             Farsi        None
# ...                 ...               ...         ...
# 9545      United States           English        None
# 9546      United States  English, Spanish        None
# 10990               NaN               NaN        None
# 10991       UA Emirates   Arabic, English        None
# 11051     United States           English        None
#
# [113 rows x 18 columns]

# %%
df_na_isoCode['birth_country'].value_counts()
# Out:
# birth_country
# Chinese Taipei          50
# IR Iran                 32
# StVincent&Grenadines     2
# UA Emirates              1
# Name: count, dtype: int64

# %%
na_isoCode_dict = { # Those codes are based on the wikipedia articles on ISO 3166-1 alpha-2
    'Chinese Taipei' : 'CN',
    'IR Iran' : 'IR',
    'UA Emirates' : 'AE',
    'StVincent&Grenadines':'VC',
    'St Kitts and Nevis' : 'KN'
}
df.loc[df['iso_country'].isna(), 'iso_country'] = (
    df.loc[df['iso_country'].isna(), 'birth_country']# use the birth country first
      .map(na_isoCode_dict)
      .fillna(df.loc[df['iso_country'].isna(), 'iso_country'])  
)
df.loc[df['iso_country'].isna(), 'iso_country'] = (
    df.loc[df['iso_country'].isna(), 'country'] # Use the country next. 
      .map(na_isoCode_dict)
      .fillna(df.loc[df['iso_country'].isna(), 'iso_country'])  
)

# %%
na_isoCode = df['iso_country'].isna().sum()
print(f"The dataset has {na_isoCode} missing iso codes")
# Out:
# The dataset has 0 missing iso codes

# %% [markdown]
# ## Flagging names

# %%
middle_name_mask = df['name'].str.strip().str.count(" ") >= 2

middle_name_count = middle_name_mask.sum()

print(f"Total rows: {df.shape[0]}")
print(f"Potential middle names: {middle_name_count}")
print(f"Percentage: {middle_name_count / df.shape[0] * 100:.2f}%")

df['hasMiddleName'] = middle_name_mask
# Out:
# Total rows: 11113
# Potential middle names: 1682
# Percentage: 15.14%

# %%
no_last_name_mask = df['name'].str.strip().str.count(" ") == 0
no_last_name_count = no_last_name_mask.sum()

print(f"Total rows: {df.shape[0]}")
print(f"Potential rows without last name: {no_last_name_count}")
print(f"Percentage: {no_last_name_count / df.shape[0] * 100:.2f}%")

df['hasNoLastName'] = no_last_name_mask
# Out:
# Total rows: 11113
# Potential rows without last name: 54
# Percentage: 0.49%

# %%
import re
import unicodedata
# This code was generated by ChatGPT and tweaked by me. 

# 1) Keep the original text; add a normalized helper column for consistent tests
def normalize_name(s):
    if pd.isna(s):
        return s
    s = unicodedata.normalize("NFKC", str(s))  # unify apostrophes/spaces, etc.
    s = s.strip()
    s = re.sub(r"\s+", " ", s)                # collapse internal whitespace
    return s

df["person_label_norm"] = df["name"].map(normalize_name)

# 2) Build masks (vectorized)
s_raw  = df["name"].astype(str)
s_norm = df["person_label_norm"].astype(str)

hyphen_mask       = s_norm.str.contains(r"-", na=False)
apostrophe_mask   = s_norm.str.contains(r"['\u2019\u02BC]", na=False)  # ', ’, ʼ
punct_mask        = s_norm.str.contains(r"[.,/&(){}\[\]<>@#?!$%^*_=+\\]", na=False)
digit_mask        = s_norm.str.contains(r"\d", na=False)
initial_mask      = s_norm.str.contains(r"(^|\s)[A-Za-z]\.", na=False)  # initials like "J."
# Non-ASCII: after NFKC, compare ASCII-stripped version to itself
non_ascii_mask    = ~s_norm.map(lambda x: x.isascii())

# Whitespace issues measured on the raw (pre-normalization) text
whitespace_mask   = s_raw.str.contains(
    r"^\s|[\u00A0\u2007\u202F]|\s{2,}|\s$", na=False
)

# 3) Combine into a single "hasDifficultName" flag
difficult_mask = (
    middle_name_mask
    | no_last_name_mask
    | hyphen_mask
    | apostrophe_mask
    | punct_mask
    | digit_mask
    | initial_mask
    | non_ascii_mask
    | whitespace_mask
)

df["hasDifficultName"] = difficult_mask

# 4) (Optional) Keep a reason code for explainability/auditing
def reason_row(i):
    reasons = []
    if middle_name_mask.iat[i]: reasons.append("middleName")
    if no_last_name_mask.iat[i]: reasons.append("noLastName")
    if hyphen_mask.iat[i]:      reasons.append("hyphen")
    if apostrophe_mask.iat[i]:  reasons.append("apostrophe")
    if punct_mask.iat[i]:       reasons.append("punctuation")
    if digit_mask.iat[i]:       reasons.append("digit")
    if initial_mask.iat[i]:     reasons.append("initials")
    if non_ascii_mask.iat[i]:   reasons.append("non_ascii")
    if whitespace_mask.iat[i]:  reasons.append("whitespace")
    return "|".join(reasons)

df["difficult_reason"] = [reason_row(i) for i in range(len(df))]

# 5) (Optional) Quick summary for your report
summary = {
    "total": len(df),
    "difficult_count": difficult_mask.sum(),
    "difficult_pct": 100 * difficult_mask.mean(),
    "by_reason": {
        "hasMiddleName" : int(middle_name_mask.sum()),
        "hasNoLastName" : int(no_last_name_mask.sum()),
        "hyphen": int(hyphen_mask.sum()),
        "apostrophe": int(apostrophe_mask.sum()),
        "punctuation": int(punct_mask.sum()),
        "digit": int(digit_mask.sum()),
        "initials": int(initial_mask.sum()),
        "non_ascii": int(non_ascii_mask.sum()),
        "whitespace": int(whitespace_mask.sum()),
    },
}
print(summary)
# Out:
# C:\Users\brief\AppData\Local\Temp\ipykernel_24276\1200723681.py:24: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   initial_mask      = s_norm.str.contains(r"(^|\s)[A-Za-z]\.", na=False)  # initials like "J."
# {'total': 11113, 'difficult_count': np.int64(2031), 'difficult_pct': np.float64(18.27589309817331), 'by_reason': {'hasMiddleName': 1682, 'hasNoLastName': 54, 'hyphen': 279, 'apostrophe': 39, 'punctuation': 11, 'digit': 2, 'initials': 8, 'non_ascii': 0, 'whitespace': 0}}

# %% [markdown]
# ## Separating non-flagged names

# %%
def split_name(full_name: str):
    tokens = full_name.strip().split()
    
    return tokens[0], tokens[1]

# Apply to dataset
df[["lastName", "surName"]] = df[df['hasDifficultName']==False]["name"].apply(
    lambda x: pd.Series(split_name(x))
)

df.head(50)
# Out:
#                              name          name_short  \
# 0                ALEKSANYAN Artur        ALEKSANYAN A
# 1                  AMOYAN Malkhas            AMOYAN M
# 2                 GALSTYAN Slavik          GALSTYAN S
# 3               HARUTYUNYAN Arsen       HARUTYUNYAN A
# 4                 TEVANYAN Vazgen          TEVANYAN V
# 5                   ARENAS Lorena            ARENAS L
# 6                 McKENZIE Ashley          McKENZIE A
# 7        BASS BITTAYE Gina Mariam     BASS BITTAYE GM
# 8                 CAMARA Ebrahima            CAMARA E
# 9             RUEDA SANTOS Lizeth      RUEDA SANTOS L
# 10         TAPIA VIDAL Rosa Maria      TAPIA VIDAL RM
# 11              GRAJALES Crisanto          GRAJALES C
# 12               MAAROUFOU Hachim         MAAROUFOU H
# 13                   SAADI Maesha             SAADI M
# 14                 DIOSDADO Nuria          DIOSDADO N
# 15                  JIMENEZ Joana           JIMENEZ J
# 16                SOBRINO Jessica           SOBRINO J
# 17                 ALFEREZ Regina           ALFEREZ R
# 18              ARELLANO Fernanda          ARELLANO F
# 19                 TOSCANO Pamela           TOSCANO P
# 20              GONZALEZ Itzamary          GONZALEZ I
# 21              RODRIGUEZ Samanta         RODRIGUEZ S
# 22                 INZUNZA Glenda           INZUNZA G
# 23                   SEHEN Sajjad             SEHEN S
# 24       RUBAIAWI Ali Ammar Yusur        RUBAIAWI AAY
# 25                 ISMAIL Mohamed            ISMAIL M
# 26                 HASSAN Ibrahim            HASSAN I
# 27                     WAISS Abdi             WAISS A
# 28            HASSAN NOUR Samiyah       HASSAN NOUR S
# 29         HOUSSEIN BARKAT Houmed   HOUSSEIN BARKAT H
# 30                     BARAT Andy             BARAT A
# 31  MARTINEZ RAMIREZ Miguel Angel  MARTINEZ RAMIREZ M
# 32     VERDE ALVAREZ Marco Alonso    VERDE ALVAREZ MA
# 33                GONZALEZ Alegna          GONZALEZ A
# 34            LOPEZ Jesus Tonatiu            LOPEZ JT
# 35                 PORTILLO Erick          PORTILLO E
# 36                    MUNOZ Uziel             MUNOZ U
# 37                 del REAL Diego          del REAL D
# 38               DOCTOR Jose Luis           DOCTOR JL
# 39                    MORAN Paola             MORAN P
# 40                   GALVAN Laura            GALVAN L
# 41              CORTES Alma Delia           CORTES AD
# 42       CRISTIAN MOSCOTE Citlali  CRISTIAN MOSCOTE C
# 43       PALMA OLIVARES Ever Jair   PALMA OLIVARES EJ
# 44          OETLING RAMIREZ Elena   OETLING RAMIREZ E
# 45    AGUILAR CHAVEZ PEON Mariana        AGUILAR CH P
# 46           LECHUGA ALANIS Kenia    LECHUGA ALANIS K
# 47            LOPEZ GARCIA Alexis      LOPEZ GARCIA A
# 48          CARBALLO NIETO Miguel    CARBALLO NIETO M
# 49                   BLANCO Luisa            BLANCO L
#
#                           name_tv  gender           function country_code  \
# 0                Artur ALEKSANYAN    Male            Athlete          ARM
# 1                  Malkhas AMOYAN    Male            Athlete          ARM
# 2                 Slavik GALSTYAN    Male            Athlete          ARM
# 3               Arsen HARUTYUNYAN    Male            Athlete          ARM
# 4                 Vazgen TEVANYAN    Male            Athlete          ARM
# 5                   Lorena ARENAS  Female            Athlete          COL
# 6                 Ashley McKENZIE    Male            Athlete          JAM
# 7        Gina Mariam BASS BITTAYE  Female            Athlete          GAM
# 8                 Ebrahima CAMARA    Male            Athlete          GAM
# 9             Lizeth RUEDA SANTOS  Female            Athlete          MEX
# 10         Rosa Maria TAPIA VIDAL  Female            Athlete          MEX
# 11              Crisanto GRAJALES    Male            Athlete          MEX
# 12               Hachim MAAROUFOU    Male            Athlete          COM
# 13                   Maesha SAADI  Female            Athlete          COM
# 14                 Nuria DIOSDADO  Female            Athlete          MEX
# 15                  Joana JIMENEZ  Female            Athlete          MEX
# 16                Jessica SOBRINO  Female            Athlete          MEX
# 17                 Regina ALFEREZ  Female            Athlete          MEX
# 18              Fernanda ARELLANO  Female            Athlete          MEX
# 19                 Pamela TOSCANO  Female            Athlete          MEX
# 20              Itzamary GONZALEZ  Female            Athlete          MEX
# 21              Samanta RODRIGUEZ  Female            Athlete          MEX
# 22                 Glenda INZUNZA  Female  Alternate Athlete          MEX
# 23                   Sajjad SEHEN    Male            Athlete          IRQ
# 24       Ali Ammar Yusur RUBAIAWI    Male            Athlete          IRQ
# 25                 Mohamed ISMAIL    Male            Athlete          DJI
# 26                 Ibrahim HASSAN    Male            Athlete          DJI
# 27                     Abdi WAISS    Male            Athlete          DJI
# 28            Samiyah HASSAN NOUR  Female            Athlete          DJI
# 29         Houmed HOUSSEIN BARKAT    Male            Athlete          DJI
# 30                     Andy BARAT    Male            Athlete          COM
# 31  Miguel Angel MARTINEZ RAMIREZ    Male            Athlete          MEX
# 32     Marco Alonso VERDE ALVAREZ    Male            Athlete          MEX
# 33                Alegna GONZALEZ  Female            Athlete          MEX
# 34            Jesus Tonatiu LOPEZ    Male            Athlete          MEX
# 35                 Erick PORTILLO    Male            Athlete          MEX
# 36                    Uziel MUNOZ    Male            Athlete          MEX
# 37                 Diego del REAL    Male            Athlete          MEX
# 38               Jose Luis DOCTOR    Male            Athlete          MEX
# 39                    Paola MORAN  Female            Athlete          MEX
# 40                   Laura GALVAN  Female            Athlete          MEX
# 41              Alma Delia CORTES  Female            Athlete          MEX
# 42       Citlali CRISTIAN MOSCOTE  Female            Athlete          MEX
# 43       Ever Jair PALMA OLIVARES    Male            Athlete          MEX
# 44          Elena OETLING RAMIREZ  Female            Athlete          MEX
# 45    Mariana AGUILAR CHAVEZ PEON  Female            Athlete          MEX
# 46           Kenia LECHUGA ALANIS  Female            Athlete          MEX
# 47            Alexis LOPEZ GARCIA    Male            Athlete          MEX
# 48          Miguel CARBALLO NIETO    Male            Athlete          MEX
# 49                   Luisa BLANCO  Female            Athlete          COL
#
#      country country_long nationality nationality_long  ... residence_country  \
# 0    Armenia      Armenia     Armenia          Armenia  ...           Armenia
# 1    Armenia      Armenia     Armenia          Armenia  ...           Armenia
# 2    Armenia      Armenia     Armenia          Armenia  ...           Armenia
# 3    Armenia      Armenia     Armenia          Armenia  ...           Armenia
# 4    Armenia      Armenia     Armenia          Armenia  ...           Armenia
# 5   Colombia     Colombia    Colombia         Colombia  ...         Australia
# 6    Jamaica      Jamaica     Jamaica          Jamaica  ...     Great Britain
# 7     Gambia       Gambia      Gambia           Gambia  ...               NaN
# 8     Gambia       Gambia      Gambia           Gambia  ...            France
# 9     Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 10    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 11    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 12   Comoros      Comoros     Comoros          Comoros  ...            France
# 13   Comoros      Comoros     Comoros          Comoros  ...            France
# 14    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 15    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 16    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 17    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 18    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 19    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 20    Mexico       Mexico      Mexico           Mexico  ...               NaN
# 21    Mexico       Mexico      Mexico           Mexico  ...               NaN
# 22    Mexico       Mexico      Mexico           Mexico  ...               NaN
# 23      Iraq         Iraq        Iraq             Iraq  ...              Iraq
# 24      Iraq         Iraq        Iraq             Iraq  ...              Iraq
# 25  Djibouti     Djibouti    Djibouti         Djibouti  ...          Djibouti
# 26  Djibouti     Djibouti    Djibouti         Djibouti  ...          Djibouti
# 27  Djibouti     Djibouti    Djibouti         Djibouti  ...               NaN
# 28  Djibouti     Djibouti    Djibouti         Djibouti  ...               NaN
# 29  Djibouti     Djibouti    Djibouti         Djibouti  ...          Djibouti
# 30   Comoros      Comoros     Comoros          Comoros  ...            France
# 31    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 32    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 33    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 34    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 35    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 36    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 37    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 38    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 39    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 40    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 41    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 42    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 43    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 44    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 45    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 46    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 47    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 48    Mexico       Mexico      Mexico           Mexico  ...            Mexico
# 49  Colombia     Colombia    Colombia         Colombia  ...               NaN
#
#                                         lang iso_country hasMiddleName  \
# 0                 Armenian, English, Russian          AM         False
# 1                                   Armenian          AM         False
# 2                                   Armenian          AM         False
# 3                                   Armenian          AM         False
# 4                          Armenian, Russian          AM         False
# 5                                    Spanish          CO         False
# 6                                    English          GB         False
# 7                            English, French          GM          True
# 8   Arabic, English, French, Mandinka, Wolof          GM         False
# 9                                    Spanish          MX          True
# 10                          English, Spanish          MX          True
# 11                                   Spanish          MX         False
# 12                                    French          FR         False
# 13                                    French          FR         False
# 14                                   Spanish          MX         False
# 15                                   Spanish          MX         False
# 16                                   Spanish          MX         False
# 17                                   Spanish          MX         False
# 18                                   Spanish          MX         False
# 19                                   Spanish          MX         False
# 20                                   Spanish          MX         False
# 21                                   Spanish          MX         False
# 22                                       NaN          MX         False
# 23                                    Arabic          IQ         False
# 24                                    Arabic          IQ          True
# 25                            French, Somali          DJ         False
# 26                                    Somali          DJ         False
# 27                            French, Somali          DJ         False
# 28                                       NaN          DJ          True
# 29                           English, French          DJ          True
# 30                                    French          KM         False
# 31                                   Spanish          MX          True
# 32                                   Spanish          MX          True
# 33                                   Spanish          MX         False
# 34                                   Spanish          MX          True
# 35                                   Spanish          MX         False
# 36                                   Spanish          MX         False
# 37                          English, Spanish          MX          True
# 38                                   Spanish          MX          True
# 39                                   Spanish          MX         False
# 40                          English, Spanish          MX         False
# 41                                   Spanish          MX          True
# 42                                   Spanish          MX          True
# 43                                   Spanish          MX          True
# 44                  English, German, Spanish          MX          True
# 45                                   Spanish          MX          True
# 46                                   Spanish          MX          True
# 47                                   Spanish          MX          True
# 48                                   Spanish          MX          True
# 49                                   English          US         False
#
#    hasNoLastName              person_label_norm hasDifficultName  \
# 0          False               ALEKSANYAN Artur            False
# 1          False                 AMOYAN Malkhas            False
# 2          False                GALSTYAN Slavik            False
# 3          False              HARUTYUNYAN Arsen            False
# 4          False                TEVANYAN Vazgen            False
# 5          False                  ARENAS Lorena            False
# 6          False                McKENZIE Ashley            False
# 7          False       BASS BITTAYE Gina Mariam             True
# 8          False                CAMARA Ebrahima            False
# 9          False            RUEDA SANTOS Lizeth             True
# 10         False         TAPIA VIDAL Rosa Maria             True
# 11         False              GRAJALES Crisanto            False
# 12         False               MAAROUFOU Hachim            False
# 13         False                   SAADI Maesha            False
# 14         False                 DIOSDADO Nuria            False
# 15         False                  JIMENEZ Joana            False
# 16         False                SOBRINO Jessica            False
# 17         False                 ALFEREZ Regina            False
# 18         False              ARELLANO Fernanda            False
# 19         False                 TOSCANO Pamela            False
# 20         False              GONZALEZ Itzamary            False
# 21         False              RODRIGUEZ Samanta            False
# 22         False                 INZUNZA Glenda            False
# 23         False                   SEHEN Sajjad            False
# 24         False       RUBAIAWI Ali Ammar Yusur             True
# 25         False                 ISMAIL Mohamed            False
# 26         False                 HASSAN Ibrahim            False
# 27         False                     WAISS Abdi            False
# 28         False            HASSAN NOUR Samiyah             True
# 29         False         HOUSSEIN BARKAT Houmed             True
# 30         False                     BARAT Andy            False
# 31         False  MARTINEZ RAMIREZ Miguel Angel             True
# 32         False     VERDE ALVAREZ Marco Alonso             True
# 33         False                GONZALEZ Alegna            False
# 34         False            LOPEZ Jesus Tonatiu             True
# 35         False                 PORTILLO Erick            False
# 36         False                    MUNOZ Uziel            False
# 37         False                 del REAL Diego             True
# 38         False               DOCTOR Jose Luis             True
# 39         False                    MORAN Paola            False
# 40         False                   GALVAN Laura            False
# 41         False              CORTES Alma Delia             True
# 42         False       CRISTIAN MOSCOTE Citlali             True
# 43         False       PALMA OLIVARES Ever Jair             True
# 44         False          OETLING RAMIREZ Elena             True
# 45         False    AGUILAR CHAVEZ PEON Mariana             True
# 46         False           LECHUGA ALANIS Kenia             True
# 47         False            LOPEZ GARCIA Alexis             True
# 48         False          CARBALLO NIETO Miguel             True
# 49         False                   BLANCO Luisa            False
#
#    difficult_reason     lastName   surName
# 0                     ALEKSANYAN     Artur
# 1                         AMOYAN   Malkhas
# 2                       GALSTYAN    Slavik
# 3                    HARUTYUNYAN     Arsen
# 4                       TEVANYAN    Vazgen
# 5                         ARENAS    Lorena
# 6                       McKENZIE    Ashley
# 7        middleName          NaN       NaN
# 8                         CAMARA  Ebrahima
# 9        middleName          NaN       NaN
# 10       middleName          NaN       NaN
# 11                      GRAJALES  Crisanto
# 12                     MAAROUFOU    Hachim
# 13                         SAADI    Maesha
# 14                      DIOSDADO     Nuria
# 15                       JIMENEZ     Joana
# 16                       SOBRINO   Jessica
# 17                       ALFEREZ    Regina
# 18                      ARELLANO  Fernanda
# 19                       TOSCANO    Pamela
# 20                      GONZALEZ  Itzamary
# 21                     RODRIGUEZ   Samanta
# 22                       INZUNZA    Glenda
# 23                         SEHEN    Sajjad
# 24       middleName          NaN       NaN
# 25                        ISMAIL   Mohamed
# 26                        HASSAN   Ibrahim
# 27                         WAISS      Abdi
# 28       middleName          NaN       NaN
# 29       middleName          NaN       NaN
# 30                         BARAT      Andy
# 31       middleName          NaN       NaN
# 32       middleName          NaN       NaN
# 33                      GONZALEZ    Alegna
# 34       middleName          NaN       NaN
# 35                      PORTILLO     Erick
# 36                         MUNOZ     Uziel
# 37       middleName          NaN       NaN
# 38       middleName          NaN       NaN
# 39                         MORAN     Paola
# 40                        GALVAN     Laura
# 41       middleName          NaN       NaN
# 42       middleName          NaN       NaN
# 43       middleName          NaN       NaN
# 44       middleName          NaN       NaN
# 45       middleName          NaN       NaN
# 46       middleName          NaN       NaN
# 47       middleName          NaN       NaN
# 48       middleName          NaN       NaN
# 49                        BLANCO     Luisa
#
# [50 rows x 25 columns]

# %%
na_surName = df['surName'].isna().sum() # Checking if no name were separated incorrectly. This should output the same number for both sur and last name. 
na_lastName = df['lastName'].isna().sum()
print(f"The dataset has {na_lastName} missing last name, and {na_surName} missing surname")
# Out:
# The dataset has 2031 missing last name, and 2031 missing surname

# %% [markdown]
# # Recording preprocessed dataset

# %%
df.to_csv('../../data/KaggleOlympic2024.csv', index=False)

# %%
check = pd.read_csv('../../data/KaggleOlympic2024.csv')
check.shape
# Out:
# (11113, 25)

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11113 entries, 0 to 11112
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               11113 non-null  object
#  1   name_short         11110 non-null  object
#  2   name_tv            11110 non-null  object
#  3   gender             11113 non-null  object
#  4   function           11113 non-null  object
#  5   country_code       11113 non-null  object
#  6   country            11113 non-null  object
#  7   country_long       11113 non-null  object
#  8   nationality        11110 non-null  object
#  9   nationality_long   11110 non-null  object
#  10  nationality_code   11110 non-null  object
#  11  birth_date         11113 non-null  object
#  12  birth_place        8727 non-null   object
#  13  birth_country      9475 non-null   object
#  14  residence_place    6804 non-null   object
#  15  residence_country  8288 non-null   object
#  16  lang               10605 non-null  object
#  17  iso_country        11109 non-null  object
#  18  hasMiddleName      11113 non-null  bool
#  19  hasNoLastName      11113 non-null  bool
#  20  person_label_norm  11113 non-null  object
#  21  hasDifficultName   11113 non-null  bool
#  22  difficult_reason   2031 non-null   object
#  23  lastName           9082 non-null   object
#  24  surName            9082 non-null   object
# dtypes: bool(3), object(22)
# memory usage: 1.9+ MB

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# residence_place      4309
# residence_country    2825
# birth_place          2386
# lastName             2031
# surName              2031
# birth_country        1638
# lang                  508
# nationality             3
# name_short              3
# nationality_code        3
# nationality_long        3
# name_tv                 3
# country                 0
# gender                  0
# name                    0
# country_code            0
# function                0
# country_long            0
# birth_date              0
# iso_country             0
# hasMiddleName           0
# person_label_norm       0
# hasNoLastName           0
# difficult_reason        0
# hasDifficultName        0
# dtype: int64
